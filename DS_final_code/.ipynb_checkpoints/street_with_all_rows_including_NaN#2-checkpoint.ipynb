# %%
import pandas as pd
import ast

#all_attributes_rows.to_csv(r'/Users/michaelcantu/Desktop/DS_final_code/all_attributes_rowswithgarage_march_3rd_1155pm',index=False)
all_attributes_rows_with_garage = pd.read_csv('/Users/michaelcantu/Desktop/DS_final_code/all_attributes_rowswithgarage_march_5th_930_no_unamed.csv',low_memory=False )

# %%
all_attributes_rows_with_garage.head()
# Out:
#   AcceptsInsurance AgesAllowed           Alcohol  \
# 0              NaN         NaN               NaN
# 1              NaN         NaN  u'beer_and_wine'
# 2              NaN         NaN               NaN
# 3              NaN         NaN               NaN
# 4              NaN         NaN               NaN
#
#                                             Ambience BYOB BYOBCorkage  \
# 0                                                NaN  NaN         NaN
# 1  {'romantic': False, 'intimate': False, 'touris...  NaN         NaN
# 2                                                NaN  NaN         NaN
# 3                                                NaN  NaN         NaN
# 4                                                NaN  NaN         NaN
#
#   BestNights BikeParking BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# 0        NaN         NaN                    NaN                        NaN
# 1        NaN        True                    NaN                       True
# ...

# %%
len(all_attributes_rows_with_garage)
# Out:
# 141914

# %%
##now just copy from the old streets, and do the same for lots and valet during NLP

# %%
all_business_parking_dicts = all_attributes_rows_with_garage['BusinessParking']

lists = []
for i in all_business_parking_dicts:
    lists.append(i)

# %%
def convert_float_to_str_afterdict(f):
    all_strs3 = []
    for i in f:
        
        if isinstance(i,float):
            #note even though you put the variable in the list you only get the new converted value
            new = str(i)
            all_strs3.append(new)
        else:
            all_strs3.append(i)
    return all_strs3

# %%
lists_of_strings_in_dict = convert_float_to_str_afterdict(lists)

# %%
lists_of_strings_in_dict
# Out:
# ['nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
# ...

# %%
def convert_nan_to_dict(q):
    temp = []
    for i in q:
        if i == 'nan':
            i = {'street' : False}
            #s = str(i)
            temp.append(i)
        elif i == 'None':
            i = {'street' : False}
            #s = str(i)
            temp.append(i)
        else:
            temp.append(i)
    return temp
all_nans_now_dicts = convert_nan_to_dict(lists_of_strings_in_dict)

# %%
all_nans_now_dicts
# Out:
# [{'street': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'street': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}",
# ...

# %%
def remove_brackets_(f):
    all_strs6 = []
    for i in f:
        
        if isinstance(i,str):
            sub = i.strip('{}') 
            all_strs6.append(sub)
            #all_strs5.append(new)
        else:
            
            all_strs6.append(i)
    return all_strs6

all_str_remove_brackets = remove_brackets_(all_nans_now_dicts)

# %%
def convert_str_to_lists(f):
    all_strs5 = []
    for i in f:
        
        if isinstance(i,str):
            sub = i.split(', ') 
            all_strs5.append(sub)
            #all_strs5.append(new)
        else:
            
            all_strs5.append(i)
    return all_strs5

all_str_now_list_had_brackets_removed = convert_str_to_lists(all_str_remove_brackets)

# %%
all_str_now_list_had_brackets_removed
# Out:
# [{'street': False},
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': True",
#   "'valet': False"],
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': True",
#   "'valet': False"],
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': True",
#   "'valet': False"],
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': False",
#   "'valet': False"],
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': False",
#   "'valet': False"],
#  {'street': False},
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': False",
#   "'valet': False"],
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
#   "'lot': False",
#   "'valet': False"],
#  ["'garage': False",
#   "'street': False",
#   "'validated': False",
# ...

# %%
def brackets_added_both_sides_edge_cases1(b):
    all_brackets = []
    for i in b:
        #print(i[0])  ##!!!<---this i thought should return "'garage' : False" it does not need to find out how to 
        ##get it so you can put {} aorund it 
        if isinstance(i,list):
            #print(i[0])
            # wrong   if i[0] == "'garage' : False":
                ###looks like you need to do a try if stament and then code to pass if no index
            if i[0] == "'street': False":
                #print(i[0])
                #print('here')
                new = '{' + i[0] + '}'
                #new1 = '{' + i[1] + '}'
                #new2 = '{' + i[2] + '}'
                #new3 = '{' + i[3] + '}'
                all_brackets.append(new)
                #all_brackets.append(new1)
                #all_brackets.append(new2)
                #all_brackets.append(new3)
            elif i[0] == "'street': True":
                pop_new = '{' + i[0] + '}'
                all_brackets.append(pop_new)   
            elif i[0] == "'valet': False":
                if len(i) > 1:
                    if i[1] == "'street': False":
                        new_add = '{' + i[1] + '}'
                        all_brackets.append(new_add)
                    #else then they are true and exist so we append them 
                    elif i[1] == "'street': True":
                        new_add2 = '{' + i[1] + '}'
                        all_brackets.append(new_add2)
                    elif i[2] == "'street': False":
                        #print(i[2])
                        new_add3 = '{' + i[2] + '}'
                        all_brackets.append(new_add3)
                    elif i[2] == "'street': True":
                        #print(i[2])
                        new_add4 = '{' + i[2] + '}'
                        all_brackets.append(new_add4)
                    elif i[3] == "'street': False":
                        #print(i[2])
                        new_add5 = '{' + i[3] + '}'
                        all_brackets.append(new_add5)
                    elif i[3] == "'street': True":
                        #print(i[2])
                        new_add6 = '{' + i[3] + '}'
                        all_brackets.append(new_add6)
                        #print(new_add2) ##didnt put the new_add2 into append
                        #all_brackets.append(new_add2)
                else:
                    #print(i) ##grabs "'valet': False"
                    i = {'street' : False}
                    ##you for got to append here~~!!! got them all 
                    all_brackets.append(i)
            ##confused as i thought this would have gotten caught by final else 
            #statement but i guess i doesnt specificalyl captue i[0] but for this 
            ##one case what was considered i?
            elif i[0] == "'valet': True":
    ###^^this one will always need to be changed cause this is the one with its own order
                last_add = '{' + i[2] + '}'
                #print(last_add)
                all_brackets.append(last_add)
            elif len(i) > 1:
                if i[1] == "'street': False":
                    new1 = '{' + i[1] + '}'
                    all_brackets.append(new1)
                elif i[2] == "'street': False":
                    new2 = '{' + i[2] + '}'
                    #print(new2)
                    all_brackets.append(new2)
                elif i[3] == "'street': False":
                    new3 = '{' + i[3] + '}'
                    all_brackets.append(new3)
                elif i[4] == "'street': False":
                    new4 = '{' + i[4] + '}'
                    #print(new4)
                    all_brackets.append(new4)
                #else:
                    ##this only did index 0 need for all indexs 
                   # the_trues = '{' + i[0] + '}'
                    #all_brackets.append(the_trues)
                elif i[0] == "'street': True":
                    true_new1 = '{' + i[0] + '}'
                    all_brackets.append(true_new1)
                elif i[1] == "'street': True":
                    true_new2 = '{' + i[1] + '}'
                    all_brackets.append(true_new2)
                elif i[2] == "'street': True":
                    true_new3 = '{' + i[2] + '}'
                    all_brackets.append(true_new3)
                elif i[3] == "'street': True":
                    true_new4 = '{' + i[3] + '}'
                    #print(true_new4)
                    all_brackets.append(true_new4)
            else:
                ##needed i[0] otherwise will append whole section
                ##**catches first index that is not 'garage' : False but still existed
                #print(i)
                i = {'street' : False} ##REMember<--this only changes i not any certain index
                #replace_not_current_column_to_false = {'garage' : False}
                #print(i)
                all_brackets.append(i)
        ##**your nan that are not grage that are not list
            
        else:
            ##even takes empty one as garage
            #print(i)
            i = {'street' : False}
            #print(i)
            all_brackets.append(i)
    return all_brackets
            
strs_over_brackets_valet_edge_cases1 = brackets_added_both_sides_edge_cases1(all_str_now_list_had_brackets_removed)
strs_over_brackets_valet_edge_cases1
# Out:
# [{'street': False},
#  "{'street': False}",
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  {'street': False},
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  {'street': False},
#  "{'street': False}",
#  {'street': False},
#  "{'street': False}",
#  {'street': False},
#  "{'street': False}",
#  "{'street': False}",
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  {'street': False},
#  "{'street': False}",
#  {'street': False},
#  {'street': False},
#  "{'street': False}",
#  {'street': False},
#  "{'street': False}",
#  "{'street': False}",
#  "{'street': False}",
#  {'street': False},
#  {'street': False},
# ...

# %%
len(strs_over_brackets_valet_edge_cases1)
# Out:
# 141914

# %%
def convert_str_to_dict(f):
    all_strs4 = []
    for i in f:
        if isinstance(i,str):
            new = ast.literal_eval(i)
            all_strs4.append(new)
        else:
            print(i)
            all_strs4.append(i)
    return all_strs4

# %%
only_dics_inList =  convert_str_to_dict(strs_over_brackets_valet_edge_cases1)
only_dics_inList
# Out:
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# {'street': False}
# ...

# %%
len(only_dics_inList)
# Out:
# 141914

# %%
dataframe_of_street_column = pd.DataFrame(only_dics_inList)

# %%
dataframe_of_street_column['street']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 141884    False
# 141885    False
# 141886    False
# 141887    False
# 141888    False
# 141889    False
# 141890    False
# 141891    False
# 141892    False
# 141893    False
# 141894    False
# 141895    False
# 141896    False
# 141897    False
# 141898    False
# 141899    False
# 141900    False
# 141901    False
# 141902    False
# 141903    False
# 141904    False
# 141905    False
# 141906    False
# 141907    False
# ...

# %%
##Proof there's no NaNs
import numpy as np
np.where(np.isnan(dataframe_of_street_column))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
dataframe_of_street_column.street.value_counts()
## 132486 + 9428 = 141914
# Out:
# False    132486
# True       9428
# Name: street, dtype: int64

# %% [markdown]
# ## Merging the single table to the main table

# %%
##thenme has garage on it now but you can rename it in the next file
all_attributes_rows_with_garage['street'] = dataframe_of_street_column['street']

# %%
all_attributes_rows_with_garage
# Out:
#        AcceptsInsurance AgesAllowed           Alcohol  \
# 0                   NaN         NaN               NaN
# 1                   NaN         NaN  u'beer_and_wine'
# 2                   NaN         NaN               NaN
# 3                   NaN         NaN               NaN
# 4                   NaN         NaN               NaN
# 5                   NaN         NaN               NaN
# 6                 False         NaN               NaN
# 7                   NaN         NaN           u'none'
# 8                   NaN         NaN   'beer_and_wine'
# 9                   NaN         NaN           u'none'
# 10                  NaN         NaN               NaN
# 11                  NaN         NaN               NaN
# 12                  NaN         NaN       u'full_bar'
# 13                  NaN         NaN               NaN
# 14                  NaN         NaN               NaN
# 15                  NaN         NaN               NaN
# ...

# %%
## figure out now how to removed unnamed:0 otherwise youll never figure it out,

# %%
all_attributes_rows_with_garage.to_csv(r'/Users/michaelcantu/Desktop/DS_final_code/all_attributes_rowswithgaragestreet_march_4th_945am.csv',index=False)

# %%
##cant figure out how to drop unnamed:0, WATCH what to click.
##never workedd
###all_attributes_rows_with_garage.drop(['Unnamed:0'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-1dae9c60b7b6> in <module>
#       1 ##cant figure out how to drop unnamed:0, WATCH what to click.
#       2
# ----> 3 all_attributes_rows_with_garage.drop(['Unnamed:0'],axis=1,inplace=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
