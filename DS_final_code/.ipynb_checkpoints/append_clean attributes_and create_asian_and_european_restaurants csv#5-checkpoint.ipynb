# %%
##now put new csv code and create the new asian and european resturants 
##then run all your models 
##then watch vixds for further ideas,
##for got if roc is a more trusted accuracy
##learn tabelu beofre saturday with data

# %%
###***as of write now you  neew to merge or concat the asian and eurpoean NEW csv, you didnt create yet, with
###the attributes colun do after you watxch video

# %%
import numpy as np
import pandas as pd
import ast

# %%
all_attributes_rows = pd.read_csv('all_attributes_rowswithgaragestreetlotvaletccprice_rangeNaNto1_march_4th_450pm.csv', low_memory=False )

# %%
all_asian_restaurants_with_unnameds = pd.read_csv('asian_only_restaurants.csv', low_memory=False )

# %%
all_asian_restaurants_with_unnameds22 = pd.read_csv('asian_only_restaurants.csv', low_memory=False )

# %%
##must redo where you dropped the unamed, first have to make indexes same as unamed
all_asian_restaurants_with_unnameds.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                        address  \
# 0           1             1               1      10110 Johnston Rd, Ste 15
# 1          57            57              57                  436 Market St
# 2          62            62              62     13843 N Tatum Blvd, Ste 15
# 3          83            83              83               4343 N Rancho Dr
# 4         105           105             105  7712 Sossamon Ln NW, Unit 140
#
#                                           attributes             business_id  \
# 0  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 1  {'OutdoorSeating': 'False', 'HasTV': 'True', '...  v-scZMU6jhnmV955RSzGJw
# 2  {'Caters': 'True', 'GoodForKids': 'True', 'Noi...  44YFU284Z3KDEy25QyVoUw
# 3                                                NaN  X8mtoSxY8whtmbDlj0D3Aw
# 4  {'NoiseLevel': "'quiet'", 'RestaurantsReservat...  L0aSDVHNXCl6sY4cfZQ-5Q
#
#                           categories        city  \
# ...

# %%
all_asian_restaurants_with_unnameds.columns = all_asian_restaurants_with_unnameds.columns.str.replace('Indexds', 'Indexes')

# %%
all_asian_restaurants_with_unnameds.head()
# Out:
#    Indexes  Indexes.1  Indexes.1.1                        address  \
# 0        1          1            1      10110 Johnston Rd, Ste 15
# 1       57         57           57                  436 Market St
# 2       62         62           62     13843 N Tatum Blvd, Ste 15
# 3       83         83           83               4343 N Rancho Dr
# 4      105        105          105  7712 Sossamon Ln NW, Unit 140
#
#                                           attributes             business_id  \
# 0  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 1  {'OutdoorSeating': 'False', 'HasTV': 'True', '...  v-scZMU6jhnmV955RSzGJw
# 2  {'Caters': 'True', 'GoodForKids': 'True', 'Noi...  44YFU284Z3KDEy25QyVoUw
# 3                                                NaN  X8mtoSxY8whtmbDlj0D3Aw
# 4  {'NoiseLevel': "'quiet'", 'RestaurantsReservat...  L0aSDVHNXCl6sY4cfZQ-5Q
#
#                           categories        city  \
# 0  Sushi Bars, Restaurants, Japanese   Charlotte
# ...

# %%
len(all_asian_restaurants)
# Out:
# 4724

# %%
all_asian_restaurants = all_asian_restaurants_with_unnameds.drop(['Indexes.1', 'Indexes.1.1'],axis = 1)

# %%
###dropp all unnamed 
all_asian_restaurants.head()
# Out:
#    Indexes                        address  \
# 0        1      10110 Johnston Rd, Ste 15
# 1       57                  436 Market St
# 2       62     13843 N Tatum Blvd, Ste 15
# 3       83               4343 N Rancho Dr
# 4      105  7712 Sossamon Ln NW, Unit 140
#
#                                           attributes             business_id  \
# 0  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 1  {'OutdoorSeating': 'False', 'HasTV': 'True', '...  v-scZMU6jhnmV955RSzGJw
# 2  {'Caters': 'True', 'GoodForKids': 'True', 'Noi...  44YFU284Z3KDEy25QyVoUw
# 3                                                NaN  X8mtoSxY8whtmbDlj0D3Aw
# 4  {'NoiseLevel': "'quiet'", 'RestaurantsReservat...  L0aSDVHNXCl6sY4cfZQ-5Q
#
#                           categories        city  \
# 0  Sushi Bars, Restaurants, Japanese   Charlotte
# 1  Japanese, Sushi Bars, Restaurants  Pittsburgh
# 2               Chinese, Restaurants     Phoenix
# ...

# %%
all_asian_restaurants_correct_index = all_asian_restaurants.set_index('Indexes')

# %%
all_asian_restaurants_correct_index
# Out:
#                                           address  \
# Indexes
# 1                       10110 Johnston Rd, Ste 15
# 57                                  436 Market St
# 62                     13843 N Tatum Blvd, Ste 15
# 83                               4343 N Rancho Dr
# 105                 7712 Sossamon Ln NW, Unit 140
# 117                 1770 W Horizon Ridge, Ste 100
# 139                 2765 N Scottsdale Rd, Ste 105
# 170                  3460 E Southern Ave, Ste 109
# 255                           10624 S Eastern Ave
# 258                                 1909 E Ray Rd
# 266                           713 W Marketview Dr
# 322                                 1703 Philo Rd
# 328                     18555 N 59th Ave, Ste 130
# 371                              2090 N Dobson Rd
# 378                     6989 N Hayden Rd, Ste A12
# 384                     955 W Chandler Heights Rd
# 393                 2765 N Scottsdale Rd, Ste 107
# ...

# %%
type(all_asian_restaurants_correct_index)
# Out:
# pandas.core.frame.DataFrame

# %%
all_asian_restaurants_correct_index.to_csv('all_asian_restaurants_correct_index.csv',index=False)

# %%
all_european_restaurants_with_unnameds = pd.read_csv('european_only_restaurants.csv', low_memory=False )

# %%
all_european_restaurants_with_unnameds.columns = all_asian_restaurants_with_unnameds.columns.str.replace('Unnamed: 0', 'Indexes')

# %%
all_european_restaurants_with_unnameds.columns
# Out:
# Index(['Indexes', 'Indexes.1', 'Indexes.1.1', 'address', 'attributes',
#        'business_id', 'categories', 'city', 'hours', 'is_open', 'latitude',
#        'longitude', 'name', 'postal_code', 'review_count', 'stars', 'state',
#        'cleaned_categories', 'asian_category', 'european_category'],
#       dtype='object')

# %%
all_european_restaurants = all_european_restaurants_with_unnameds.drop(['Indexes.1', 'Indexes.1.1'],axis = 1)

# %%
all_european_restaurants.head()
# Out:
#    Indexes                           address  \
# 0        9                   5981 Andrews Rd
# 1       12      1775 E Tropicana Ave, Ste 29
# 2       25                6401 Morrison Blvd
# 3       51                     4606 Penn Ave
# 4      100  Artisan Hotel, 1501 W Sahara Ave
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': '2', 'BusinessAccep...  fweCYi8FmbJXHCqLnwuk8w
# 1  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
# 2  {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...  BvYU3jvGd0TJ7IyZdfiN2Q
# 3  {'CoatCheck': 'False', 'BusinessParking': "{'g...  dQj5DLZjeDK3KFysh1SYOQ
# 4  {'RestaurantsAttire': "'dressy'", 'Corkage': '...  bJP4l_BGq2CudEu0m-wNjg
#
#                                           categories                city  \
# 0         Italian, Restaurants, Pizza, Chicken Wings  Mentor-on-the-Lake
# 1                               Restaurants, Italian           Las Vegas
# ...

# %%
all_european_restaurants_correct_index = all_european_restaurants.set_index('Indexes')

# %%
all_european_restaurants_correct_index.to_csv('all_european_restaurants_correct_index_march_5th_1120.csv')

# %%
all_european_restaurants_correct_index.head()
# Out:
#                                   address  \
# Indexes
# 9                         5981 Andrews Rd
# 12           1775 E Tropicana Ave, Ste 29
# 25                     6401 Morrison Blvd
# 51                          4606 Penn Ave
# 100      Artisan Hotel, 1501 W Sahara Ave
#
#                                                 attributes  \
# Indexes
# 9        {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 12       {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 25       {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...
# 51       {'CoatCheck': 'False', 'BusinessParking': "{'g...
# 100      {'RestaurantsAttire': "'dressy'", 'Corkage': '...
#
#                     business_id  \
# Indexes
# 9        fweCYi8FmbJXHCqLnwuk8w
# 12       PZ-LZzSlhSe9utkQYU8pFg
# 25       BvYU3jvGd0TJ7IyZdfiN2Q
# 51       dQj5DLZjeDK3KFysh1SYOQ
# 100      bJP4l_BGq2CudEu0m-wNjg
#
#                                                 categories  \
# Indexes
# ...

# %%
len(all_european_restaurants)
# Out:
# 3930

# %%
all_european_restaurants.head()
# Out:
#                             address  \
# 0                   5981 Andrews Rd
# 1      1775 E Tropicana Ave, Ste 29
# 2                6401 Morrison Blvd
# 3                     4606 Penn Ave
# 4  Artisan Hotel, 1501 W Sahara Ave
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': '2', 'BusinessAccep...  fweCYi8FmbJXHCqLnwuk8w
# 1  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
# 2  {'Alcohol': "u'full_bar'", 'BusinessAcceptsCre...  BvYU3jvGd0TJ7IyZdfiN2Q
# 3  {'CoatCheck': 'False', 'BusinessParking': "{'g...  dQj5DLZjeDK3KFysh1SYOQ
# 4  {'RestaurantsAttire': "'dressy'", 'Corkage': '...  bJP4l_BGq2CudEu0m-wNjg
#
#                                           categories                city  \
# 0         Italian, Restaurants, Pizza, Chicken Wings  Mentor-on-the-Lake
# 1                               Restaurants, Italian           Las Vegas
# ...

# %%
len(all_attributes_rows)
# Out:
# 141914

# %%
all_attributes_rows.head()
# Out:
#   AcceptsInsurance AgesAllowed           Alcohol  \
# 0              NaN         NaN               NaN
# 1              NaN         NaN  u'beer_and_wine'
# 2              NaN         NaN               NaN
# 3              NaN         NaN               NaN
# 4              NaN         NaN               NaN
#
#                                             Ambience BYOB BYOBCorkage  \
# 0                                                NaN  NaN         NaN
# 1  {'romantic': False, 'intimate': False, 'touris...  NaN         NaN
# 2                                                NaN  NaN         NaN
# 3                                                NaN  NaN         NaN
# 4                                                NaN  NaN         NaN
#
#   BestNights BikeParking BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# 0        NaN         NaN                    NaN                        NaN
# 1        NaN        True                    NaN                       True
# ...

# %%
#all_attributes_rows
