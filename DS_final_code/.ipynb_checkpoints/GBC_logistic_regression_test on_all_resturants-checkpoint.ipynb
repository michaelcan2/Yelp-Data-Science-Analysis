# %%
import numpy as np
import pandas as pd
import ast

business_pd_Dat = pd.read_csv('cleaned_bus_pd_Dat.csv', low_memory=False)

# %%
len(business_pd_Dat)
# Out:
# 141914

# %%
all_attributes_rows = pd.read_csv('all_attributes_rowswithgaragestreetlotvaletccprice_rangeNaNto1_march_4th_450pm.csv', low_memory=False)

# %%
len(all_attributes_rows)
# Out:
# 141914

# %%
all_merge = pd.merge(business_pd_Dat, all_attributes_rows, left_index=True, right_index=True)

# %%
len(all_merge)
# Out:
# 141914

# %%
all_merge.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               address  \
# 0           0             0           2818 E Camino Acequia Drive
# 1           1             1             10110 Johnston Rd, Ste 15
# 2           2             2         15655 W Roosevelt St, Ste 237
# 3           3             3        4209 Stuart Andrew Blvd, Ste F
# 4           4             4  4545 E Tropicana Rd Ste 8, Tropicana
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 2                                                NaN  xvX2CttrVhyG2z1dFg_0xw
# 3  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
# 4  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
#
#                                           categories       city  \
# ...

# %%
dropped = all_merge.drop(['Unnamed: 0'],axis = 1)

# %%
dropped.head()
# Out:
#    Unnamed: 0.1                               address  \
# 0             0           2818 E Camino Acequia Drive
# 1             1             10110 Johnston Rd, Ste 15
# 2             2         15655 W Roosevelt St, Ste 237
# 3             3        4209 Stuart Andrew Blvd, Ste F
# 4             4  4545 E Tropicana Rd Ste 8, Tropicana
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 2                                                NaN  xvX2CttrVhyG2z1dFg_0xw
# 3  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
# 4  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
#
#                                           categories       city  \
# 0                                  Golf, Active Life    Phoenix
# ...

# %%
dropped.columns = dropped.columns.str.replace('Unnamed: 0.1', 'index_final')

# %%
dropped.head()
# Out:
#    index_final                               address  \
# 0            0           2818 E Camino Acequia Drive
# 1            1             10110 Johnston Rd, Ste 15
# 2            2         15655 W Roosevelt St, Ste 237
# 3            3        4209 Stuart Andrew Blvd, Ste F
# 4            4  4545 E Tropicana Rd Ste 8, Tropicana
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'GoodForKids': 'True', 'NoiseLevel': "u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 2                                                NaN  xvX2CttrVhyG2z1dFg_0xw
# 3  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
# 4  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
#
#                                           categories       city  \
# 0                                  Golf, Active Life    Phoenix
# ...

# %%
final_all_merge = dropped.set_index("index_final")

# %%
final_all_merge.head()
# Out:
#                                           address  \
# index_final
# 0                     2818 E Camino Acequia Drive
# 1                       10110 Johnston Rd, Ste 15
# 2                   15655 W Roosevelt St, Ste 237
# 3                  4209 Stuart Andrew Blvd, Ste F
# 4            4545 E Tropicana Rd Ste 8, Tropicana
#
#                                                     attributes  \
# index_final
# 0                                     {'GoodForKids': 'False'}
# 1            {'GoodForKids': 'True', 'NoiseLevel': "u'avera...
# 2                                                          NaN
# 3            {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
# 4            {'RestaurantsPriceRange2': '3', 'GoodForKids':...
#
#                         business_id  \
# index_final
# 0            1SWheh84yJXfytovILXOAQ
# 1            gnKjwL_1w79qoiV3IC_xQQ
# 2            xvX2CttrVhyG2z1dFg_0xw
# 3            HhyxOkGAM07SRYtlQ4wMFQ
# 4            gbQN7vr_caG_A1ugSmGhWg
#
# ...

# %%
##now copy and past eall the algorithms to it

# %%
star_ratings_all = final_all_merge['stars']

# %%
review_count_all = final_all_merge['review_count']

# %%
logistic_x_features_all = final_all_merge[['valet','garage','street','lot','AcceptsCreditCards','review_count','price ranges NaN to 1']]

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
my_logistic_regression = LogisticRegression()

# %%
def convert(v):
    updated = []
    for i in v:
        if i > 3:
            updated.append(1)
        else:
            updated.append(0)
    return updated

# %%
binary_from_threshold_all = convert(star_ratings_all)

# %%
star_ratings_reshape_all = np.array(star_ratings_all).reshape(-1,1)

# %%
review_count_reshape_all = np.array(review_count_all).reshape(-1,1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
rescaled_features = scaler.fit_transform(logistic_x_features_all)

# %%
##before normilizing
from sklearn.model_selection import cross_val_score
Log_reg_scores_all = cross_val_score(my_logistic_regression, logistic_x_features_all, binary_from_threshold_all , cv =5, scoring='accuracy').mean()
Log_reg_scores_all
# Out:
# 0.6740913511713222

# %%
##normilizng isnt really making a difference
from sklearn.model_selection import cross_val_score
Log_reg_scores_all_normalized = cross_val_score(my_logistic_regression, rescaled_features, binary_from_threshold_all , cv =5, scoring='accuracy').mean()
Log_reg_scores_all_normalized
# Out:
# 0.6740913511713222
