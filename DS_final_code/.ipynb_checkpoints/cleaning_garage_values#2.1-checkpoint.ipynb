# %%
#this is garage for all rows you did i
##***!!! when pasting code into final report 
##have this one duplicated and then and the simple functions and big function used that
#are different for each key value pair.

###give each convert_nan_to_dict funciton indiviual names like Garage_convert_nan_to_dict
##street_convert_nan_to_dict etc..

##the big one is brackets_added_both_sides_edge_cases1 give each indiviudal name all in one 
##jupyter notebook and called something like garage_brackets_added_both_sides_edge_cases1
#streetbrackets_added_both_sides_edge_cases1 etc...

# %%
Quesiotn1:-unamed

Question2:- show i merge it our just use df[] = []
i ask b/c its all the feautes from with all the clean attributes trying to merge with just
asian resturants, its not just one column being added on like iwas doing while the in the
process of creating one big cleaan busines.json attributes



Quesiton 2: further ml tasks to do 
###have to clean all these attributes firsts and then you merge asiant resurants and the big
##attributes,,, can the indexes work connect first index 9, from eu to attbutes .csv that
##starts with 0

# %%
import pandas as pd
import ast


all_attributes_rows = pd.read_csv('final_all_atts_with_nans_141914_rows_march_3_1130pm.csv',low_memory=False )

# %%
all_attributes_rows.columns
# Out:
# Index(['Unnamed: 0', 'AcceptsInsurance', 'AgesAllowed', 'Alcohol', 'Ambience',
#        'BYOB', 'BYOBCorkage', 'BestNights', 'BikeParking',
#        'BusinessAcceptsBitcoin', 'BusinessAcceptsCreditCards',
#        'BusinessParking', 'ByAppointmentOnly', 'Caters', 'CoatCheck',
#        'Corkage', 'DietaryRestrictions', 'DogsAllowed', 'DriveThru',
#        'GoodForDancing', 'GoodForKids', 'GoodForMeal', 'HairSpecializesIn',
#        'HappyHour', 'HasTV', 'Music', 'NaN_here', 'NoiseLevel', 'Open24Hours',
#        'OutdoorSeating', 'RestaurantsAttire', 'RestaurantsCounterService',
#        'RestaurantsDelivery', 'RestaurantsGoodForGroups',
#        'RestaurantsPriceRange2', 'RestaurantsReservations',
#        'RestaurantsTableService', 'RestaurantsTakeOut', 'Smoking',
#        'WheelchairAccessible', 'WiFi'],
#       dtype='object')

# %%
all_attributes_rows.head()
# Out:
#    Unnamed: 0 AcceptsInsurance AgesAllowed           Alcohol  \
# 0           0              NaN         NaN               NaN
# 1           1              NaN         NaN  u'beer_and_wine'
# 2           2              NaN         NaN               NaN
# 3           3              NaN         NaN               NaN
# 4           4              NaN         NaN               NaN
#
#                                             Ambience BYOB BYOBCorkage  \
# 0                                                NaN  NaN         NaN
# 1  {'romantic': False, 'intimate': False, 'touris...  NaN         NaN
# 2                                                NaN  NaN         NaN
# 3                                                NaN  NaN         NaN
# 4                                                NaN  NaN         NaN
#
#   BestNights BikeParking BusinessAcceptsBitcoin  ...    \
# 0        NaN         NaN                    NaN  ...
# 1        NaN        True                    NaN  ...
# 2        NaN         NaN                    NaN  ...
# 3        NaN         NaN                  False  ...
# 4        NaN       False                    NaN  ...
#
#   RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 0                       NaN                 NaN                      NaN
# 1                       NaN               False                     True
# 2                       NaN                 NaN                      NaN
# 3                       NaN                 NaN                      NaN
# 4                       NaN                 NaN                      NaN
#
#   RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 0                    NaN                     NaN                     NaN
# 1                      2                    True                    True
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                      3                     NaN                     NaN
#
#   RestaurantsTakeOut Smoking WheelchairAccessible   WiFi
# 0                NaN     NaN                  NaN    NaN
# 1               True     NaN                  NaN  u'no'
# 2                NaN     NaN                  NaN    NaN
# 3                NaN     NaN                  NaN    NaN
# 4                NaN     NaN                  NaN    NaN
#
# [5 rows x 41 columns]

# %%
len(all_attributes_rows)
# Out:
# 141914

# %%
all_business_parking_dicts = all_attributes_rows['BusinessParking']

lists = []
for i in all_business_parking_dicts:
    lists.append(i)

# %%
def convert_float_to_str_afterdict(f):
    all_strs3 = []
    for i in f:
        
        if isinstance(i,float):
            #note even though you put the variable in the list you only get the new converted value
            new = str(i)
            all_strs3.append(new)
        else:
            all_strs3.append(i)
    return all_strs3

# %%
lists_of_strings_in_dict = convert_float_to_str_afterdict(lists)

# %%
lists_of_strings_in_dict
# Out:
# ['nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': True, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'None',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': True, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'None',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'None',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'None',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'None',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'None',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'nan',
#  'nan',
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  'nan',
#  'nan',
#  ...]

# %%
def convert_nan_to_dict(q):
    temp = []
    for i in q:
        if i == 'nan':
            i = {'garage' : False}
            #s = str(i)
            temp.append(i)
        elif i == 'None':
            i = {'garage' : False}
            #s = str(i)
            temp.append(i)
        else:
            temp.append(i)
    return temp
all_nans_now_dicts = convert_nan_to_dict(lists_of_strings_in_dict)

# %%
all_nans_now_dicts
# Out:
# [{'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': True, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': True, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'valet': False, 'garage': False, 'street': False, 'lot': True, 'validated': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  {'garage': False},
#  {'garage': False},
#  ...]

# %%
def remove_brackets_(f):
    all_strs_list5 = []
    for i in f:
        
        if isinstance(i,str):
            sub = i.strip('{}') 
            all_strs_list5.append(sub)
            #all_strs5.append(new)
        else:
            
            all_strs_list5.append(i)
    return all_strs_list5

all_str_remove_brackets = remove_brackets_(all_nans_now_dicts)

# %%
def convert_str_to_lists(f):
    all_strs_list6 = []
    for i in f:
        
        if isinstance(i,str):
            sub = i.split(', ') 
            all_strs_list6.append(sub)
          
        else:
            
            all_strs_list6.append(i)
    return all_strs_list6

all_str_now_list_had_brackets_removed = convert_str_to_lists(all_str_remove_brackets)

# %%
###wokring on now
def brackets_added_both_sides_edge_cases1(b):
    all_brackets = []
    for i in b:
        #print(i[0])  ##!!!<---this i thought should return "'garage' : False" it does not need to find out how to 
        ##get it so you can put {} aorund it 
        if isinstance(i,list):
           
            if i[0] == "'garage': False":
               
                new = '{' + i[0] + '}'
               
                all_brackets.append(new)
              
            elif i[0] == "'garage': True":
                pop_new = '{' + i[0] + '}'
                all_brackets.append(pop_new)   
            elif i[0] == "'valet': False":
                if len(i) > 1:
                    if i[1] == "'garage': False":
                        new_add = '{' + i[1] + '}'
                        all_brackets.append(new_add)
                    #else then they are true and exist so we append them 
                    else:
                        #print(i[1])
                        new_add2 = '{' + i[1] + '}'
                        #print(new_add2) ##didnt put the new_add2 into append
                        all_brackets.append(new_add2)
                else:
                    #print(i) ##grabs "'valet': False"
                    i = {'garage' : False}
                    ##you for got to append here~~!!! got them all 
                    all_brackets.append(i)
            ##confused as i thought this would have gotten caught by final else 
            #statement but i guess i doesnt specificalyl captue i[0] but for this 
            ##one case what was considered i?
            elif i[0] == "'valet': True":
                last_add = '{' + i[1] + '}'
                all_brackets.append(last_add)
            elif len(i) > 1:
                if i[1] == "'garage': False":
                    new1 = '{' + i[1] + '}'
                    all_brackets.append(new1)
                elif i[2] == "'garage': False":
                    new2 = '{' + i[2] + '}'
                    all_brackets.append(new2)
                elif i[3] == "'garage': False":
                    new3 = '{' + i[3] + '}'
                    all_brackets.append(new3)
                elif i[4] == "'garage': False":
                    new4 = '{' + i[4] + '}'
                    all_brackets.append(new4)
                #else:
                    ##this only did index 0 need for all indexs 
                   # the_trues = '{' + i[0] + '}'
                    #all_brackets.append(the_trues)
                elif i[0] == "'garage': True":
                    true_new1 = '{' + i[0] + '}'
                    all_brackets.append(true_new1)
                elif i[1] == "'garage': True":
                    true_new2 = '{' + i[1] + '}'
                    all_brackets.append(true_new2)
                elif i[2] == "'garage': True":
                    true_new3 = '{' + i[2] + '}'
                    all_brackets.append(true_new3)
                elif i[3] == "'garage': True":
                    true_new4 = '{' + i[3] + '}'
                    all_brackets.append(true_new4)
            else:
                ##needed i[0] otherwise will append whole section
                ##**catches first index that is not 'garage' : False but still existed
                #print(i)
                i = {'garage' : False} ##REMember<--this only changes i not any certain index
                #replace_not_current_column_to_false = {'garage' : False}
                all_brackets.append(i)
        ##**your nan that are not grage that are not list
            
        else:
            ##even takes empty one as garage
            #print(i)
            i = {'garage' : False}
            #print(i)
            all_brackets.append(i)
    return all_brackets
            
strs_over_brackets_valet_edge_cases1 = brackets_added_both_sides_edge_cases1(all_str_now_list_had_brackets_removed)
strs_over_brackets_valet_edge_cases1
# Out:
# [{'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': False}",
#  "{'garage': True}",
#  {'garage': False},
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  "{'garage': True}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  "{'garage': False}",
#  "{'garage': True}",
#  "{'garage': False}",
#  "{'garage': False}",
#  {'garage': False},
#  {'garage': False},
#  ...]

# %%
len(strs_over_brackets_valet_edge_cases1)
# Out:
# 141914

# %%
def convert_str_to_dict(f):
    all_strs4 = []
    for i in f:
        if isinstance(i,str):
            new = ast.literal_eval(i)
            all_strs4.append(new)
        else:
            print(i)
            all_strs4.append(i)
    return all_strs4

# %%
only_dics_inList =  convert_str_to_dict(strs_over_brackets_valet_edge_cases1)
only_dics_inList
# Out:
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# {'garage': False}
# ...
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': True},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  {'garage': False},
#  ...]

# %%
type(only_dics_inList)
# Out:
# list

# %%
len(only_dics_inList)
# Out:
# 141914

# %%
dataframe_of_garage_column = pd.DataFrame(only_dics_inList)

# %%
##Proof there's no NaNs
import numpy as np
np.where(np.isnan(dataframe_of_garage_column))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
dataframe_of_garage_column.garage.value_counts()
# Out:
# False    137480
# True       4434
# Name: garage, dtype: int64

# %% [markdown]
# ## Merging the single table to the main table

# %%
##the name has all_attributes_rows on it now but you can rename it in the next file
##in order to keep track on what has been added to it.

all_attributes_rows['garage'] = dataframe_of_garage_column['garage']

# %%
len(all_attributes_rows['garage'])
# Out:
# 141914

# %%
all_attributes_rows.head()
# Out:
#    Unnamed: 0 AcceptsInsurance AgesAllowed           Alcohol  \
# 0           0              NaN         NaN               NaN
# 1           1              NaN         NaN  u'beer_and_wine'
# 2           2              NaN         NaN               NaN
# 3           3              NaN         NaN               NaN
# 4           4              NaN         NaN               NaN
#
#                                             Ambience BYOB BYOBCorkage  \
# 0                                                NaN  NaN         NaN
# 1  {'romantic': False, 'intimate': False, 'touris...  NaN         NaN
# 2                                                NaN  NaN         NaN
# 3                                                NaN  NaN         NaN
# 4                                                NaN  NaN         NaN
#
#   BestNights BikeParking BusinessAcceptsBitcoin  ...   RestaurantsDelivery  \
# 0        NaN         NaN                    NaN  ...                   NaN
# 1        NaN        True                    NaN  ...                 False
# 2        NaN         NaN                    NaN  ...                   NaN
# 3        NaN         NaN                  False  ...                   NaN
# 4        NaN       False                    NaN  ...                   NaN
#
#   RestaurantsGoodForGroups RestaurantsPriceRange2 RestaurantsReservations  \
# 0                      NaN                    NaN                     NaN
# 1                     True                      2                    True
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 4                      NaN                      3                     NaN
#
#   RestaurantsTableService RestaurantsTakeOut Smoking WheelchairAccessible  \
# 0                     NaN                NaN     NaN                  NaN
# 1                    True               True     NaN                  NaN
# 2                     NaN                NaN     NaN                  NaN
# 3                     NaN                NaN     NaN                  NaN
# 4                     NaN                NaN     NaN                  NaN
#
#     WiFi garage
# 0    NaN  False
# 1  u'no'  False
# 2    NaN  False
# 3    NaN  False
# 4    NaN  False
#
# [5 rows x 42 columns]

# %%
all_attributes_rows.to_csv(r'/Users/michaelcantu/Desktop/DS_final_code/all_attributes_rowswithgarage_march_3rd_1155pm',index=False)
